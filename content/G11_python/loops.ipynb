# %% [markdown]
# # Schleifen

# %% [markdown]
# Du hast im ByCS-Kurs die Theorie zur for und While Schleife gelesen. Jetzt ist es Zeit zur Anwendung!
# Schreibe eine *for*-Schleife, die nach dem Start (=strg+enter) die folgende Ausgabe liefert:
# 0
# 1
# 2
# 3

# %%
for ..........................
    print(i)
