# %% [markdown]
# # Funktionen mit Parametern

# %% [markdown]
# Du kennst Funktionen mit Parametern aus der Mathematik -- sie haben dort
# immer die gleichen, langweiligen Namen: f, sin, cos, ... und der Parmeter
# ist `x`.
# In der Informatik sollten Funktionsnamen aussagekräftig sein!
# Ergänze nachfolgende Funktion so, dass der Code funktioniert:

# %%
def quadrieren(x):
    ... dein Code ...
    print(ergebnis)

### Aufruf ###
quadrieren(4)
quadrieren(7)
quadrieren(-2)

# %% [markdown]
# Was am Anfang irritiert, sind die Namen der Variablen - die können
# nämlich **innerhalb** der Funktion anders sein, als außerhalb.
# Sieh dir folgendes Beispiel an:

# %%
def verdoppeln(zahl):
    print(2*x)

def halbieren(eingabe):
    print(eingabe/2)

##### Aufruf

preis = 25         # diese Variable ist "außen"
verdoppeln(preis)  # eigentlich steht hier verdoppeln(25)
halbieren(preis)   # und hier halbieren 25

# %% [markdown]
# Die Variable „wert“ und die Variablen „zahl“ und „eingabe“ haben also
# eigentlich nichts miteinander zu tun, weil als Parameter der Wert von `preis`
# verwendet wird.

# %% [markdown]
# # Aufgaben

# %% [markdown]
# ## 1. Doppelte
# Hier musst du Funktionen und Schleifen kombinieren
#
# > Schreibe eine Funktion, die alle Doppelten der Zahlen
# > bis zu einer Obergrenze ausgibt.
#
# **Beispiel**
# `doppelt(4)`liefert als Ausgabe die Zahlen 0,2,4,6,8
# `doppelt(5)`liefert als Ausgabe die Zahlen 0,2,4,6,8,10

# %%
# Dein Code

# %% [markdown]
# ## 2. Doppelte mit Bereich
# Nun sollst du deine Funktion von oben so anpassen, dass du
# eine Untergrenze und eine Obergrenze angeben kannst, dass
# also als Ausgaben entstehen:
#
# `6,8,10,12` oder `20,22,24,26`

# %% [markdown]
# ## 3. Doppelt, aber bitte keine 4er!
# Das ist ein Sonderwunsch eines Kunden, der eine Allergie gegen die Zahl 4
# hat. Filtere bei der Ausgabe alle Ergebnisse heraus, die auf „4“ enden!
# Dafür wirst du etwas mit `if` basteln müssen!
